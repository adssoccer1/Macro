# %% [markdown]
# **Aidan Sinclair - 1/19/25 - [Linkedin](https://www.linkedin.com/in/aidan-sinclair/) - [Twitter](https://x.com/aidansinclair_)**
#
# # How Volatility Was Killed In 2023
#
# Monetary authorities in the U.S. have interpreted their dual mandates of price stability and maximum employment into a twisted translation of total stability and a zero tolerance policy for volatility. It appears as though the Fed and the Treasury would like to catch every wobble and smooth the business cycle so all that remains is a steady secular trend up.
#
# Combined with the unstoppable fiscal trajectory spurred by its own populist political dynamic that will not easily digest spending cuts, the Monetary and Fiscal powers have effectively killed the business cycle... for now.
#
#  ![Screenshot 2025-01-08 at 11.25.27 AM.png](attachment:c77fdf95-4346-4bd6-9376-747cb8259281.png)
#
# The consistent dampening of economic volatility is a primary reason asset prices have the confidence to rise to the levels we see today. Artificially low interest rates, years of QE followed by “fake” QT, ample liquidity reserves for failing banks such as SVB (perhaps we will deal with moral hazard later), activist Treasury issuance, twin deficits,  are all factors in the function that has effectively killed volatility. These stimuli have propelled America’s outperformance. Corprate and household balance sheets, corprate margins, and productivity are at record levels. But the death of volaility is the true propulsive force higher.
#
# When authorities reveal they are about to use one of their tools, markets move, generally setting a new positive trend; hence, monitoring the authority’s most powerful weapons is crucial. There will be windows of time when these tools are rolled off and no easing is taking place. These will be periods of potential vulnerability.
#
# The focus of this piece is on the most recent financial engineering that U.S. Treasury deployed in 2023 to continue to artificially smooth the business cycle.
# ![Screenshot 2025-01-23 at 11.43.39 AM.png](attachment:ad75cfb8-0980-4108-b567-7377e99de33d.png)

# %% [markdown]
# ### Some Background
#
# The **total central bank reserves held by depository institutions at the Federal Reserve** include both [required reserves](https://fred.stlouisfed.org/seriesBeta/REQRESNS) (which have been cut to zero since March 2020) and [excess reserves](https://fred.stlouisfed.org/seriesBeta/EXCSRESNS) ... which are now all reserves! This does not include the TGA, which is a non-reserve account at the Fed.
#
# ![Screenshot 2025-01-08 at 2.31.19 PM.png](attachment:9d343f70-e314-4194-907a-b868c722ed63.png)
#
# [link](https://fred.stlouisfed.org/seriesBeta/TOTRESNS)
#
# Central Bank reserves are just money for the interbank ecosystem system so banks can meet settlements and liquidity needs in that ecosystem. They are not dispersed into the "real economy", per se. But they are a key liquidity monitor for the banking system. If banks ever encounter funding stress they have to fire sell assets which is systemically risky.... hence the lowest level of adequate reserves is always being evaluated.
#
# Setting rates on the Interest on Reserve Balances (IORB) and the Reverse Repo Facility (RRP) is how the Fed sets a floor on short term rates. They offer a rate for lenders with excess liquidity to earn the Fed's target rate on their funds, rather than forcing them to participate in markets that may not offer as competitive a return. This drives the rates offered for liquidity in those markets up to the Fed's target rate and absorbs excess liquidity in the banking ecosystem.
#
# For example, if Goldman Sachs has excess liquidity, to earn a return on that liquidity they will look to private repo markets, where rates are tied to the Secured Overnight Financing Rate (SOFR). If SOFR falls below the IORB rate, Goldman Sachs can deposit its money at the Fed to earn the IORB instead of lending in the repo market. This reduces liquidity in the repo market, pushing SOFR back up toward the IORB rate.
#
# If a money market fund, like Fidelity Government Money Market Fund, needs to park cash overnight while ensuring they can meet settlement obligations for withdrawing investors, they can lend in the Fed Funds Market or private repo markets. However, if the rates they earn there are too low, they can lend to the Fed via the RRP. The RRP offers a risk-free, collateralized option at the RRP rate, ensuring a competitive return and thereby reducing liquidity in other markets that are below the RRP rate, pushing those rates higher.
#
# How can we observe liquidity in the interbank[or intra ?) lending system?
#
# - We can see volumes in the RRP [here](https://fred.stlouisfed.org/graph/?g=EPMW)
# - We can see volumes on private repo markets via SOFR rates and volumes [here](https://www.newyorkfed.org/markets/reference-rates/sofr)
# - We can see volumes in Fed Funds markets via Effective Fed Funds Rates (EFFR) and volumes [here](https://www.newyorkfed.org/markets/reference-rates/effr)

# %% [markdown]
# ### So what happened in October 2023 that put a clear bottom in U.S. equities?
#
# Since the QRA on July 31st it was clear the market was having trouble digesting the huge amount of coupon issuance. A huge selloff in bonds had been putting downward pressure on equities, clearly seen in the above SPY chart.
#
# On October 30, 2023, the Treasury released its QRA and surprised the market with an increase in bill issuance marking a dramatic halt to the summer's decline in bonds and equites.
#
# ![Screenshot 2025-01-23 at 1.00.41 PM.png](attachment:502d1063-964d-4158-b305-77ac6b942965.png)
#
# Of course, shifting Treasury issuance to the front end of the curve is always stimulative, but Yellen recognized she could increase bill isusance because of the nearly 2 trillion dollars in the RRP! The money market funds demand liquid assets like T-bills and there was 2 trillion dollars of that demand waiting to be moved back into private markets and out of the RRP. How perfect to refill the TGA!
#
# When the increase in T-bill supply hit the market it moved private repo rates up, widening the spread between the RRP rate and short term treasuries. Observe how the widening spread between these two rates correlates with the depletion of funds in the RRP! This was RRP participants redploying their funds into higher-yielding alternatives. In this case RRP funds flowed into T-bills, and then those sellers of T-bills need to move further out the risk curve and so you get a shift of funds ultimately impacting corporate bonds, high-yield debt, and equities, and tightening credit spreads.

# %%
from fredapi import Fred
import pandas as pd
import matplotlib.pyplot as plt

fred_api_key = 'b1b93f854d911b3cdc94df6dd9ec0365' ##pls dont use lol ;)
fred = Fred(api_key=fred_api_key)

# Fetch ON RRP Rate which is (RRPONTSYD) and the 4week T-bill yield (DTB4WK)
try:
    on_rrp = fred.get_series('RRPONTSYAWARD')
    t_bill_4wk = fred.get_series('DTB4WK')
except Exception as e:
    print(f"Error fetching data from FRED: {e}")
    raise

data = pd.concat([on_rrp, t_bill_4wk], axis=1)
data.columns = ['ON_RRP_Rate', '4Wk_TBill_Yield']
data['Spread'] = data['ON_RRP_Rate'] - data['4Wk_TBill_Yield']

data.dropna(inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Spread'], label='Spread (ON RRP Rate - 4Wk T-Bill Yield)', color='blue', linewidth=2)
plt.axhline(0, color='gray', linestyle='--', linewidth=1)
plt.title('Spread Between ON RRP Rate and 4-Week Treasury Bill Yield', fontsize=14)
plt.ylabel('Spread (%)', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.legend(loc='upper left', fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Observe how the RRP drains and bill issuance increases in 2023:
#
# ![Screenshot 2025-01-08 at 6.05.53 PM.png](attachment:655529c0-9c2a-46a5-bd11-8cb8bbf06dc3.png)
#
# Thinking like the Fed and the Treasury is so important when hypothesizing future policy. We know they want to smooth the business cycle. What tools do they have at their disposal and any given time and how might they engineer their desired outcomes?
