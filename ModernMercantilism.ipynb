# %% [markdown]
# August 1, 2025 - Modern Mercantilism Challenge.
#
# Paper: [here](https://github.com/adssoccer1/Macro/blob/main/Modern%20Mercantilism%20Challenge/Aidan_Sinclair_A_Reflexive_Rebalancing.pdf)
#
# Jupyter Notebook for supporting code/charts: [here](https://github.com/adssoccer1/Macro/tree/main/Modern%20Mercantilism%20Challenge)
