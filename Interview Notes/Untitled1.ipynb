# %% [markdown]
# They have a pretty cool graph of forward returns based off of inflatin and growth. Interestingly high inflation and high growth does not have good forward return. Guess that makes sense. And low growth low inflation has the best returns.
# ![Screenshot 2025-03-06 at 9.40.37 AM.png](attachment:b4d94a2c-dd65-443c-8ebb-b8107739ce46.png)
#
# The increase in the 10 year in the fall and winter is still working its way through the economy and its being compounded by the tariff uncertainty.
#
# A real estate investment trust (REIT) is a company that owns, manages, or finances real estate properties to generate income. REITs are similar to mutual funds and exchange-traded funds (ETFs).
#
# Monitoring etf flows and options activity in REITS (or any other sector you are analyzing is valid). Sees that options markets are trying to exploit the downside rather than the upside.
