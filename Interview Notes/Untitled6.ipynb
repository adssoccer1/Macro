# %% [markdown]
# In this environment, fiscal policy is more important than monetary policy. With the exsiting amount of debt outstanding and the current fiscal deficits, which is tied to the amount of debt outstanding due to interest expense ---> these dynamics are more impactful to the economy than plus or minues 50bps of rates.
#
# When the public sector is borrowing more money than the entire private sector, then raising rates has limited impact, other than ironically spilling more money into the private sector when rates rise.
#
# The big beautiful bill is about what is going to continue to happen.
