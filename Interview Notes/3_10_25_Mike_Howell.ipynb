# %% [markdown]
# Michael Howell 3/10/25 [Keeping it Simple | Ep. 46: With a Liquid Howell, She Cried More, More, More
# ](https://www.youtube.com/watch?v=r6Qd-pC0wJ8&list=WL&index=2)
#
#
# There are different ways of measuring or defining liquidity. Market liquidity and funding liquidity. Howell focuses on funding liquidity which is the cash savings and credit through global financial markets.
#
# Total amount of an asset divided by its duration. A long duration asset is a lot less liquid that a short duration asset.
#
# When people talk about money supply they often leave out credit. Plus the volatility of an asset determines its liquidity and how much it can be used as collateral.
#
# The mov index which measures bond volatility affects liquidity, because if there is more volaitlity in bonds, they are less valuable as collateral.
#
# Howell says if we revalue our gold reserves, we can add it to the TGA? which means we wouldnt have to refill it?
#
# Howell says his usual thing about how debt-gdp is meaningless and debt-liquidity is what matters.
#
# Howell is projecting increase in global liquidity later this year....globally CBs are still easing, commercial banks are still lending, MOVE index is calming which is liquidity postive.
#
# There is obviously a difference in liquidity that is in the real economy and in financial markets. When liquidity leaves the financial markets and goes into the real economy that is not always so good for asset prices. And when the real economy does poorly asset prices can do well because of the liquidity injected into the financial markets, but not the real economy.
#
# How financial liquidity enters the real economy is what matters.
#
# Global liquidity is independent and twice the size of global GDP. 175 trillion of global liquidity vs 115 trillion of gdp
