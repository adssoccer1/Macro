# %% [markdown]
# 6/7/25 [Nothing Stops This Train w/ Lyn Alden | Bitcoin 2025
# ](https://www.youtube.com/watch?v=Giuzcd4oxIk&list=WL&index=1)
#
# During recessions unemployment goes up and deficits go up and during better times the relationship stays positive. But after covid, this relationship has decoupled. We have had shrinking unemploument, and yet the discal deficit as a % of GDP has continued to not only stay high but continue to go back up.
#
# We have also seen a decoupling from real rates and gold. These are the two primary rererves assets around the word. Treasury yeilds and gold.
#
# So why would there be a complete decoupling from gold and real rates after covid?
#
# When looking at private sector debt growth( bank loans and corporate bonds) vs federal debt growth.
#
# Lyn's main idea is that when the fed raises rates, they increase federal debt, more than they decrease private sector debt. Which means the fed doesnt have brakes anymore. They dont have a way to contrain total credit growth in this system.
