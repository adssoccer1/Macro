# %% [markdown]
# Melody Wright
#
# Inventory built up in the spring, but we still saw low sales in the summer for existing home prices.
#
# The housing market is divided between new homes and existing homes.
#
# Builders have now over built, especially in texas. So new homes are being priced lower than existing homes. This is because sellers are "delusional".
#
# First time home buyers are the lowest ever currently since the 80s.
